# %%
# !pip list
# Out:
# Package                                           Version
# ------------------------------------------------- -----------
# aiohttp                                           3.7.4
# alembic                                           1.8.1
# allensdk                                          2.13.4
# aniso8601                                         9.0.1
# anyio                                             3.6.1
# appnope                                           0.1.3
# argon2-cffi                                       21.3.0
# argon2-cffi-bindings                              21.2.0
# argschema                                         3.0.4
# async-timeout                                     3.0.1
# attrs                                             21.4.0
# autopep8                                          1.6.0
# Babel                                             2.10.3
# backcall                                          0.2.0
# beautifulsoup4                                    4.11.1
# ...

# %%
# %pip list
# Out:
# Package              Version
# -------------------- ---------
# appnope              0.1.2
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# attrs                21.4.0
# autopep8             1.6.0
# backcall             0.2.0
# bleach               4.1.0
# Bottleneck           1.3.2
# brotlipy             0.7.0
# cached-property      1.5.2
# certifi              2021.10.8
# cffi                 1.15.0
# charset-normalizer   2.0.4
# cryptography         36.0.0
# cycler               0.11.0
# Cython               0.29.28
# debugpy              1.5.1
# decorator            5.1.1
# defusedxml           0.7.1
# entrypoints          0.3
# fonttools            4.25.0
# h5py                 3.6.0
# idna                 3.3
# importlib-metadata   4.8.2
# ipykernel            6.9.1
# ipython              7.31.1
# ipython-genutils     0.2.0
# ipywidgets           7.7.0
# jedi                 0.18.1
# Jinja2               3.1.2
# json5                0.9.6
# ...

# %%
import appnope

# %%
# !which python
# Out:
# /Users/pfc/miniconda3/envs/tvb-mac/bin/python

# %%
# !where python
# Out:
# /Users/pfc/miniconda3/envs/tvb-mac/bin/python
# /usr/local/bin/python

# %%
import
