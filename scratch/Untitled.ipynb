# %%
# !conda list
# Out:
# # packages in environment at /Users/pfc/miniconda3/envs/tvb-mac:
# #
# # Name                    Version                   Build  Channel
# aiohttp                   3.7.4                    pypi_0    pypi
# alembic                   1.8.1                    pypi_0    pypi
# allensdk                  2.13.4                   pypi_0    pypi
# aniso8601                 9.0.1                    pypi_0    pypi
# anyio                     3.6.1                    pypi_0    pypi
# appnope                   0.1.3                    pypi_0    pypi
# argon2-cffi               21.3.0                   pypi_0    pypi
# argon2-cffi-bindings      21.2.0                   pypi_0    pypi
# argschema                 3.0.4                    pypi_0    pypi
# async-timeout             3.0.1                    pypi_0    pypi
# attrs                     21.4.0             pyhd3eb1b0_0
# babel                     2.10.3                   pypi_0    pypi
# backcall                  0.2.0                    pypi_0    pypi
# beautifulsoup4            4.11.1                   pypi_0    pypi
# biplist                   1.0.3                    pypi_0    pypi
# blas                      1.0                    openblas
# bleach                    5.0.1                    pypi_0    pypi
# blosc                     1.21.0               h8346a28_1
# boto3                     1.17.21                  pypi_0    pypi
# botocore                  1.20.112                 pypi_0    pypi
# bzip2                     1.0.8                h1de35cc_0
# c-ares                    1.18.1               h0d85af4_0    conda-forge
# ca-certificates           2022.6.15            h033912b_0    conda-forge
# cachetools                4.2.4                    pypi_0    pypi
# certifi                   2022.6.15        py37hf985489_0    conda-forge
# cffi                      1.15.0           py37hc55c11b_1
# cfflib                    2.0.5                    pypi_0    pypi
# chardet                   3.0.4                    pypi_0    pypi
# charset-normalizer        2.1.0                    pypi_0    pypi
# cheroot                   8.5.2            py37hecd8cb5_1
# cherrypy                  18.6.0           py37hecd8cb5_0
# click                     7.1.2                    pypi_0    pypi
# cloudpickle               2.0.0              pyhd3eb1b0_0
# coverage                  6.3.2            py37hca72f7f_0
# cryptography              37.0.1           py37hf6deb26_0
# cycler                    0.11.0             pyhd3eb1b0_0
# cython                    0.29.30          py37he9d5cce_0
# cytoolz                   0.11.0           py37haf1e3a3_0
# dask-core                 2021.10.0          pyhd3eb1b0_0
# dataclasses               0.8                pyh6d0b6a4_7
# debugpy                   1.6.2                    pypi_0    pypi
# decorator                 5.1.1                    pypi_0    pypi
# defusedxml                0.7.1                    pypi_0    pypi
# distro                    1.7.0                    pypi_0    pypi
# dmgbuild                  1.5.2                    pypi_0    pypi
# docutils                  0.18.1           py37hecd8cb5_3
# ds-store                  1.3.0                    pypi_0    pypi
# ecdsa                     0.18.0                   pypi_0    pypi
# entrypoints               0.4                      pypi_0    pypi
# execnet                   1.9.0              pyhd3eb1b0_0
# fastjsonschema            2.16.1                   pypi_0    pypi
# flask                     1.1.4                    pypi_0    pypi
# flask-restx               0.5.1                    pypi_0    pypi
# formencode                2.0.1                    pypi_0    pypi
# freetype                  2.11.0               hd8bbffd_0
# fsspec                    2022.3.0         py37hecd8cb5_0
# future                    0.18.2                   pypi_0    pypi
# gevent                    21.12.0          py37h69ee0a8_1    conda-forge
# giflib                    5.2.1                haf1e3a3_0
# glymur                    0.8.19                   pypi_0    pypi
# greenlet                  1.1.2            py37hd8d24ac_1    conda-forge
# h5py                      2.10.0                   pypi_0    pypi
# hdf5                      1.10.4               hfa1e0ec_0
# hdmf                      3.3.2                    pypi_0    pypi
# idna                      3.3                      pypi_0    pypi
# imageio                   2.9.0              pyhd3eb1b0_0
# importlib-metadata        4.11.3           py37hecd8cb5_0
# importlib-resources       5.8.0                    pypi_0    pypi
# importlib_metadata        4.11.3               hd3eb1b0_0
# iniconfig                 1.1.1              pyhd3eb1b0_0
# ipykernel                 6.15.1                   pypi_0    pypi
# ipython                   7.34.0                   pypi_0    pypi
# ipython-genutils          0.2.0                    pypi_0    pypi
# itsdangerous              1.1.0                    pypi_0    pypi
# jaraco.classes            3.2.1              pyhd3eb1b0_0
# jaraco.collections        3.3.0              pyhd3eb1b0_0
# jaraco.functools          3.3.0              pyhd3eb1b0_0
# jaraco.text               3.5.1            py37hecd8cb5_2
# jedi                      0.18.1                   pypi_0    pypi
# jinja2                    2.11.3                   pypi_0    pypi
# jmespath                  0.10.0                   pypi_0    pypi
# joblib                    1.1.0              pyhd3eb1b0_0
# jpeg                      9e                   hca72f7f_0
# json5                     0.9.8                    pypi_0    pypi
# jsonschema                4.7.2                    pypi_0    pypi
# jupyter-client            7.3.4                    pypi_0    pypi
# jupyter-core              4.11.1                   pypi_0    pypi
# jupyter-server            1.18.1                   pypi_0    pypi
# jupyterlab                3.4.4                    pypi_0    pypi
# jupyterlab-pygments       0.2.2                    pypi_0    pypi
# jupyterlab-server         2.15.0                   pypi_0    pypi
# kiwisolver                1.4.2            py37he9d5cce_0
# krb5                      1.19.2               hcd88c3b_0
# lcms2                     2.12                 hf1fd2bf_0
# libcxx                    12.0.0               h2f01273_0
# libedit                   3.1.20210910         hca72f7f_0
# libev                     4.33                 haf1e3a3_1    conda-forge
# libffi                    3.3                  hb1e8313_2
# libgfortran               3.0.1                h93005f0_2
# libllvm11                 11.1.0               h46f1229_1
# libopenblas               0.3.20               h9a5756b_0
# libpng                    1.6.37               ha441bb4_0
# libpq                     12.9                 h1c9f633_3
# libtiff                   4.2.0                hdb42f99_1
# libuv                     1.44.2               hac89ed1_0    conda-forge
# libwebp                   1.2.2                h56c3ce4_0
# libwebp-base              1.2.2                hca72f7f_0
# llvm-openmp               12.0.0               h0dcd299_1
# llvmlite                  0.38.0           py37h8346a28_0
# locket                    1.0.0            py37hecd8cb5_0
# lockfile                  0.12.2                   pypi_0    pypi
# lz4-c                     1.9.3                h23ab428_1
# lzo                       2.10                 haf1e3a3_2
# mac-alias                 2.2.0                    pypi_0    pypi
# mako                      1.2.1                    pypi_0    pypi
# markupsafe                2.1.1                    pypi_0    pypi
# marshmallow               3.17.0                   pypi_0    pypi
# matplotlib                3.1.3                    py37_0
# matplotlib-base           3.1.3            py37h9aa3819_0
# matplotlib-inline         0.1.3                    pypi_0    pypi
# mistune                   0.8.4                    pypi_0    pypi
# mock                      4.0.3              pyhd3eb1b0_0
# more-itertools            8.12.0             pyhd3eb1b0_0
# multidict                 6.0.2                    pypi_0    pypi
# nbclassic                 0.4.3                    pypi_0    pypi
# nbclient                  0.6.6                    pypi_0    pypi
# nbconvert                 6.5.0                    pypi_0    pypi
# nbformat                  5.4.0                    pypi_0    pypi
# ncurses                   6.3                  hca72f7f_3
# ndx-events                0.2.0                    pypi_0    pypi
# nest-asyncio              1.5.5                    pypi_0    pypi
# networkx                  2.6.3              pyhd3eb1b0_0
# nibabel                   4.0.1                    pypi_0    pypi
# nomkl                     3.0                           0
# notebook                  6.4.12                   pypi_0    pypi
# notebook-shim             0.1.0                    pypi_0    pypi
# numba                     0.55.1           py37hae1ba45_0
# numexpr                   2.8.3            py37h0f1bd0b_0
# numpy                     1.18.1           py37h0c13f30_0
# numpy-base                1.18.1           py37hc72aeb7_1
# olefile                   0.46               pyh9f0ad1d_1    conda-forge
# openssl                   1.1.1q               hfe4f2af_0    conda-forge
# packaging                 21.3               pyhd3eb1b0_0
# pandas                    1.3.5                    pypi_0    pypi
# pandocfilters             1.5.0                    pypi_0    pypi
# parso                     0.8.3                    pypi_0    pypi
# partd                     1.2.0              pyhd3eb1b0_1
# patsy                     0.5.2                    pypi_0    pypi
# pexpect                   4.8.0                    pypi_0    pypi
# pickleshare               0.7.5                    pypi_0    pypi
# pillow                    7.2.0            py37hf860fee_2    conda-forge
# pip                       22.2                     pypi_0    pypi
# pluggy                    1.0.0            py37hecd8cb5_1
# portend                   2.7.1              pyhd3eb1b0_0
# prometheus-client         0.14.1                   pypi_0    pypi
# prompt-toolkit            3.0.30                   pypi_0    pypi
# psutil                    5.9.0            py37hca72f7f_0
# psycopg2                  2.8.6            py37hbcfaee0_1
# psycopg2-binary           2.9.3                    pypi_0    pypi
# ptyprocess                0.7.0                    pypi_0    pypi
# py                        1.11.0             pyhd3eb1b0_0
# py-cpuinfo                8.0.0              pyhd3eb1b0_1
# pyaescrypt                6.0.0                    pypi_0    pypi
# pyasn1                    0.4.8                    pypi_0    pypi
# pycparser                 2.21               pyhd3eb1b0_0
# pygments                  2.12.0                   pypi_0    pypi
# pyjwt                     2.4.0                    pypi_0    pypi
# pynrrd                    0.4.3                    pypi_0    pypi
# pynwb                     2.1.0                    pypi_0    pypi
# pyobjc                    8.5                      pypi_0    pypi
# pyobjc-core               8.5                      pypi_0    pypi
# pyobjc-framework-accessibility 8.5                      pypi_0    pypi
# pyobjc-framework-accounts 8.5                      pypi_0    pypi
# pyobjc-framework-addressbook 8.5                      pypi_0    pypi
# pyobjc-framework-adservices 8.5                      pypi_0    pypi
# pyobjc-framework-adsupport 8.5                      pypi_0    pypi
# pyobjc-framework-applescriptkit 8.5                      pypi_0    pypi
# pyobjc-framework-applescriptobjc 8.5                      pypi_0    pypi
# pyobjc-framework-applicationservices 8.5                      pypi_0    pypi
# pyobjc-framework-apptrackingtransparency 8.5                      pypi_0    pypi
# pyobjc-framework-audiovideobridging 8.5                      pypi_0    pypi
# pyobjc-framework-authenticationservices 8.5                      pypi_0    pypi
# pyobjc-framework-automaticassessmentconfiguration 8.5                      pypi_0    pypi
# pyobjc-framework-automator 8.5                      pypi_0    pypi
# pyobjc-framework-avfoundation 8.5                      pypi_0    pypi
# pyobjc-framework-avkit    8.5                      pypi_0    pypi
# pyobjc-framework-businesschat 8.5                      pypi_0    pypi
# pyobjc-framework-calendarstore 8.5                      pypi_0    pypi
# pyobjc-framework-callkit  8.5                      pypi_0    pypi
# pyobjc-framework-cfnetwork 8.5                      pypi_0    pypi
# pyobjc-framework-classkit 8.5                      pypi_0    pypi
# pyobjc-framework-cloudkit 8.5                      pypi_0    pypi
# pyobjc-framework-cocoa    8.5                      pypi_0    pypi
# pyobjc-framework-collaboration 8.5                      pypi_0    pypi
# pyobjc-framework-colorsync 8.5                      pypi_0    pypi
# pyobjc-framework-contacts 8.5                      pypi_0    pypi
# pyobjc-framework-contactsui 8.5                      pypi_0    pypi
# pyobjc-framework-coreaudio 8.5                      pypi_0    pypi
# pyobjc-framework-coreaudiokit 8.5                      pypi_0    pypi
# pyobjc-framework-corebluetooth 8.5                      pypi_0    pypi
# pyobjc-framework-coredata 8.5                      pypi_0    pypi
# pyobjc-framework-corehaptics 8.5                      pypi_0    pypi
# pyobjc-framework-corelocation 8.5                      pypi_0    pypi
# pyobjc-framework-coremedia 8.5                      pypi_0    pypi
# pyobjc-framework-coremediaio 8.5                      pypi_0    pypi
# pyobjc-framework-coremidi 8.5                      pypi_0    pypi
# pyobjc-framework-coreml   8.5                      pypi_0    pypi
# pyobjc-framework-coremotion 8.5                      pypi_0    pypi
# pyobjc-framework-coreservices 8.5                      pypi_0    pypi
# pyobjc-framework-corespotlight 8.5                      pypi_0    pypi
# pyobjc-framework-coretext 8.5                      pypi_0    pypi
# pyobjc-framework-corewlan 8.5                      pypi_0    pypi
# pyobjc-framework-cryptotokenkit 8.5                      pypi_0    pypi
# pyobjc-framework-datadetection 8.5                      pypi_0    pypi
# pyobjc-framework-devicecheck 8.5                      pypi_0    pypi
# pyobjc-framework-dictionaryservices 8.5                      pypi_0    pypi
# pyobjc-framework-discrecording 8.5                      pypi_0    pypi
# pyobjc-framework-discrecordingui 8.5                      pypi_0    pypi
# pyobjc-framework-diskarbitration 8.5                      pypi_0    pypi
# pyobjc-framework-dvdplayback 8.5                      pypi_0    pypi
# pyobjc-framework-eventkit 8.5                      pypi_0    pypi
# pyobjc-framework-exceptionhandling 8.5                      pypi_0    pypi
# pyobjc-framework-executionpolicy 8.5                      pypi_0    pypi
# pyobjc-framework-externalaccessory 8.5                      pypi_0    pypi
# pyobjc-framework-fileprovider 8.5                      pypi_0    pypi
# pyobjc-framework-fileproviderui 8.5                      pypi_0    pypi
# pyobjc-framework-findersync 8.5                      pypi_0    pypi
# pyobjc-framework-fsevents 8.5                      pypi_0    pypi
# pyobjc-framework-gamecenter 8.5                      pypi_0    pypi
# pyobjc-framework-gamecontroller 8.5                      pypi_0    pypi
# pyobjc-framework-gamekit  8.5                      pypi_0    pypi
# pyobjc-framework-gameplaykit 8.5                      pypi_0    pypi
# pyobjc-framework-imagecapturecore 8.5                      pypi_0    pypi
# pyobjc-framework-imserviceplugin 8.5                      pypi_0    pypi
# pyobjc-framework-inputmethodkit 8.5                      pypi_0    pypi
# pyobjc-framework-installerplugins 8.5                      pypi_0    pypi
# pyobjc-framework-instantmessage 8.5                      pypi_0    pypi
# pyobjc-framework-intents  8.5                      pypi_0    pypi
# pyobjc-framework-intentsui 8.5                      pypi_0    pypi
# pyobjc-framework-iosurface 8.5                      pypi_0    pypi
# pyobjc-framework-ituneslibrary 8.5                      pypi_0    pypi
# pyobjc-framework-kernelmanagement 8.5                      pypi_0    pypi
# pyobjc-framework-latentsemanticmapping 8.5                      pypi_0    pypi
# pyobjc-framework-launchservices 8.5                      pypi_0    pypi
# pyobjc-framework-libdispatch 8.5                      pypi_0    pypi
# pyobjc-framework-linkpresentation 8.5                      pypi_0    pypi
# pyobjc-framework-localauthentication 8.5                      pypi_0    pypi
# pyobjc-framework-localauthenticationembeddedui 8.5                      pypi_0    pypi
# pyobjc-framework-mailkit  8.5                      pypi_0    pypi
# pyobjc-framework-mapkit   8.5                      pypi_0    pypi
# pyobjc-framework-mediaaccessibility 8.5                      pypi_0    pypi
# pyobjc-framework-medialibrary 8.5                      pypi_0    pypi
# pyobjc-framework-mediaplayer 8.5                      pypi_0    pypi
# pyobjc-framework-mediatoolbox 8.5                      pypi_0    pypi
# pyobjc-framework-metal    8.5                      pypi_0    pypi
# pyobjc-framework-metalkit 8.5                      pypi_0    pypi
# pyobjc-framework-metalperformanceshaders 8.5                      pypi_0    pypi
# pyobjc-framework-metalperformanceshadersgraph 8.5                      pypi_0    pypi
# pyobjc-framework-metrickit 8.5                      pypi_0    pypi
# pyobjc-framework-mlcompute 8.5                      pypi_0    pypi
# pyobjc-framework-modelio  8.5                      pypi_0    pypi
# pyobjc-framework-multipeerconnectivity 8.5                      pypi_0    pypi
# pyobjc-framework-naturallanguage 8.5                      pypi_0    pypi
# pyobjc-framework-netfs    8.5                      pypi_0    pypi
# pyobjc-framework-network  8.5                      pypi_0    pypi
# pyobjc-framework-networkextension 8.5                      pypi_0    pypi
# pyobjc-framework-notificationcenter 8.5                      pypi_0    pypi
# pyobjc-framework-opendirectory 8.5                      pypi_0    pypi
# pyobjc-framework-osakit   8.5                      pypi_0    pypi
# pyobjc-framework-oslog    8.5                      pypi_0    pypi
# pyobjc-framework-passkit  8.5                      pypi_0    pypi
# pyobjc-framework-pencilkit 8.5                      pypi_0    pypi
# pyobjc-framework-photos   8.5                      pypi_0    pypi
# pyobjc-framework-photosui 8.5                      pypi_0    pypi
# pyobjc-framework-preferencepanes 8.5                      pypi_0    pypi
# pyobjc-framework-pushkit  8.5                      pypi_0    pypi
# pyobjc-framework-quartz   8.5                      pypi_0    pypi
# pyobjc-framework-quicklookthumbnailing 8.5                      pypi_0    pypi
# pyobjc-framework-replaykit 8.5                      pypi_0    pypi
# pyobjc-framework-safariservices 8.5                      pypi_0    pypi
# pyobjc-framework-scenekit 8.5                      pypi_0    pypi
# pyobjc-framework-screencapturekit 8.5                      pypi_0    pypi
# pyobjc-framework-screensaver 8.5                      pypi_0    pypi
# pyobjc-framework-screentime 8.5                      pypi_0    pypi
# pyobjc-framework-scriptingbridge 8.5                      pypi_0    pypi
# pyobjc-framework-searchkit 8.5                      pypi_0    pypi
# pyobjc-framework-security 8.5                      pypi_0    pypi
# pyobjc-framework-securityfoundation 8.5                      pypi_0    pypi
# pyobjc-framework-securityinterface 8.5                      pypi_0    pypi
# pyobjc-framework-servicemanagement 8.5                      pypi_0    pypi
# pyobjc-framework-shazamkit 8.5                      pypi_0    pypi
# pyobjc-framework-social   8.5                      pypi_0    pypi
# pyobjc-framework-soundanalysis 8.5                      pypi_0    pypi
# pyobjc-framework-speech   8.5                      pypi_0    pypi
# pyobjc-framework-spritekit 8.5                      pypi_0    pypi
# pyobjc-framework-storekit 8.5                      pypi_0    pypi
# pyobjc-framework-syncservices 8.5                      pypi_0    pypi
# pyobjc-framework-systemconfiguration 8.5                      pypi_0    pypi
# pyobjc-framework-systemextensions 8.5                      pypi_0    pypi
# pyobjc-framework-uniformtypeidentifiers 8.5                      pypi_0    pypi
# pyobjc-framework-usernotifications 8.5                      pypi_0    pypi
# pyobjc-framework-usernotificationsui 8.5                      pypi_0    pypi
# pyobjc-framework-videosubscriberaccount 8.5                      pypi_0    pypi
# pyobjc-framework-videotoolbox 8.5                      pypi_0    pypi
# pyobjc-framework-virtualization 8.5                      pypi_0    pypi
# pyobjc-framework-vision   8.5                      pypi_0    pypi
# pyobjc-framework-webkit   8.5                      pypi_0    pypi
# pyopenssl                 22.0.0             pyhd3eb1b0_0
# pyparsing                 3.0.4              pyhd3eb1b0_0
# pyrsistent                0.18.1                   pypi_0    pypi
# pytables                  3.6.1            py37h5bccee9_0
# pytest                    7.1.2            py37hecd8cb5_0
# pytest-benchmark          3.4.1            py37hecd8cb5_1
# pytest-cov                3.0.0              pyhd3eb1b0_0
# pytest-forked             1.3.0              pyhd3eb1b0_0
# pytest-mock               3.7.0            py37hecd8cb5_0
# pytest-xdist              2.5.0              pyhd3eb1b0_0
# python                    3.7.13               hdfd78df_0
# python-dateutil           2.8.2              pyhd3eb1b0_0
# python-jose               3.3.0                    pypi_0    pypi
# python-keycloak           2.1.1                    pypi_0    pypi
# python-magic-bin          0.4.14                   pypi_0    pypi
# python_abi                3.7                     2_cp37m    conda-forge
# pytz                      2022.1           py37hecd8cb5_0
# pyunicore                 0.6.0                    pypi_0    pypi
# pywavelets                1.1.1            py37haf1e3a3_2
# pyyaml                    6.0              py37hca72f7f_1
# pyzmq                     23.2.0                   pypi_0    pypi
# readline                  8.1.2                hca72f7f_1
# repoze.lru                0.7              py37hecd8cb5_0
# requests                  2.28.1                   pypi_0    pypi
# requests-toolbelt         0.9.1                    pypi_0    pypi
# routes                    2.5.1            py37hecd8cb5_0
# rsa                       4.9                      pypi_0    pypi
# ruamel-yaml               0.17.21                  pypi_0    pypi
# ruamel-yaml-clib          0.2.6                    pypi_0    pypi
# s3transfer                0.3.7                    pypi_0    pypi
# scikit-build              0.15.0                   pypi_0    pypi
# scikit-image              0.14.2           py37h0a44026_0
# scikit-learn              1.0.2            py37hae1ba45_1
# scipy                     1.7.3            py37hfb86763_0
# seaborn                   0.11.2                   pypi_0    pypi
# semver                    2.13.0                   pypi_0    pypi
# send2trash                1.8.0                    pypi_0    pypi
# setuptools                61.2.0           py37hecd8cb5_0
# simpleitk                 2.1.1.2                  pypi_0    pypi
# simplejson                3.17.6           py37hca72f7f_0
# six                       1.16.0             pyhd3eb1b0_1
# sniffio                   1.2.0                    pypi_0    pypi
# soupsieve                 2.3.2.post1              pypi_0    pypi
# sqlalchemy                1.4.39                   pypi_0    pypi
# sqlite                    3.38.5               h707629a_0
# statsmodels               0.13.0                   pypi_0    pypi
# subprocess32              3.5.4                    pypi_0    pypi
# syncrypto                 0.4.2                    pypi_0    pypi
# tbb                       2021.5.0             haf03e11_0
# tempora                   4.1.1              pyhd3eb1b0_0
# terminado                 0.15.0                   pypi_0    pypi
# threadpoolctl             2.2.0              pyh0d69192_0
# tinycss2                  1.1.1                    pypi_0    pypi
# tk                        8.6.12               h5d9f67b_0
# toml                      0.10.2             pyhd3eb1b0_0
# tomli                     2.0.1            py37hecd8cb5_0
# toolz                     0.11.2             pyhd3eb1b0_0
# tornado                   6.1              py37h9ed2024_0
# tqdm                      4.64.0                   pypi_0    pypi
# traitlets                 5.3.0                    pypi_0    pypi
# tvb-gdist                 2.1.0                    pypi_0    pypi
# typing_extensions         4.1.1              pyh06a4308_0
# urllib3                   1.26.10                  pypi_0    pypi
# wcwidth                   0.2.5                    pypi_0    pypi
# webencodings              0.5.1                    pypi_0    pypi
# websocket-client          1.3.3                    pypi_0    pypi
# werkzeug                  1.0.1                    pypi_0    pypi
# wheel                     0.37.1             pyhd3eb1b0_0
# xarray                    0.15.1                   pypi_0    pypi
# xz                        5.2.5                hca72f7f_1
# yaml                      0.2.5                haf1e3a3_0
# yarl                      1.7.2                    pypi_0    pypi
# zc.lockfile               2.0                pyhd3eb1b0_0
# zipp                      3.8.0            py37hecd8cb5_0
# zlib                      1.2.12               h4dc903c_2
# zope.event                4.5.0              pyh9f0ad1d_0    conda-forge
# zope.interface            5.4.0            py37h69ee0a8_2    conda-forge
# zstd                      1.5.2                hcb37349_0

# %%
# %pylab inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('pylab', 'inline')
#
# File /usr/local/Cellar/ipython/8.3.0/libexec/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2304, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2302     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2303 with self.builtin_trap:
# -> 2304     result = fn(*args, **kwargs)
#    2305 return result
#
# File /usr/local/Cellar/ipython/8.3.0/libexec/lib/python3.10/site-packages/IPython/core/magics/pylab.py:155, in PylabMagics.pylab(self, line)
#     151 else:
#     152     # invert no-import flag
#     153     import_all = not args.no_import_all
# --> 155 gui, backend, clobbered = self.shell.enable_pylab(args.gui, import_all=import_all)
#     156 self._show_matplotlib_backend(args.gui, backend)
#     157 print(
#     158     "%pylab is deprecated, use %matplotlib inline and import the required libraries."
#     159 )
#
# File /usr/local/Cellar/ipython/8.3.0/libexec/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3526, in InteractiveShell.enable_pylab(self, gui, import_all, welcome_message)
#    3499 """Activate pylab support at runtime.
#    3500
#    3501 This turns on support for matplotlib, preloads into the interactive
#    (...)
#    3522     This argument is ignored, no welcome message will be displayed.
#    3523 """
#    3524 from IPython.core.pylabtools import import_pylab
# -> 3526 gui, backend = self.enable_matplotlib(gui)
#    3528 # We want to prevent the loading of pylab to pollute the user's
#    3529 # namespace as shown by the %who* magics, so we execute the activation
#    3530 # code in an empty namespace, and we update *both* user_ns and
#    3531 # user_ns_hidden with this information.
#    3532 ns = {}
#
# File /usr/local/Cellar/ipython/8.3.0/libexec/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3472, in InteractiveShell.enable_matplotlib(self, gui)
#    3451 def enable_matplotlib(self, gui=None):
#    3452     """Enable interactive matplotlib and inline figure support.
#    3453
#    3454     This takes the following steps:
#    (...)
#    3470         display figures inline.
#    3471     """
# -> 3472     from matplotlib_inline.backend_inline import configure_inline_support
#    3474     from IPython.core import pylabtools as pt
#    3475     gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#
# File /usr/local/Cellar/ipython/8.3.0/libexec/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:6, in <module>
#       1 """A matplotlib backend for publishing figures via display_data"""
#       3 # Copyright (c) IPython Development Team.
#       4 # Distributed under the terms of the BSD 3-Clause License.
# ----> 6 import matplotlib
#       7 from matplotlib.backends.backend_agg import (  # noqa
#       8     new_figure_manager,
#       9     FigureCanvasAgg,
#      10     new_figure_manager_given_figure,
#      11 )
#      12 from matplotlib import colors
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# %conda list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('conda', 'list')
#
# File /usr/local/Cellar/ipython/8.3.0/libexec/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2304, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2302     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2303 with self.builtin_trap:
# -> 2304     result = fn(*args, **kwargs)
#    2305 return result
#
# File /usr/local/Cellar/ipython/8.3.0/libexec/lib/python3.10/site-packages/IPython/core/magics/packaging.py:87, in PackagingMagics.conda(self, line)
#      81 """Run the conda package manager within the current kernel.
#      82
#      83 Usage:
#      84   %conda install [pkgs]
#      85 """
#      86 if not _is_conda_environment():
# ---> 87     raise ValueError("The python kernel does not appear to be a conda environment.  "
#      88                      "Please use ``%pip install`` instead.")
#      90 conda = _get_conda_executable()
#      91 args = shlex.split(line)
#
# ValueError: The python kernel does not appear to be a conda environment.  Please use ``%pip install`` instead.

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'

# %%
#Create and run the monitor/analyser
bold_model = bold.BalloonModel(time_series = tsr)
#bold_data  = bold_model.evaluate()

# %%
def balloon_dfun(self, state_variables, neural_input, local_coupling=0.0):
    r"""
    The Balloon model equations. See Eqs. (4-10) in [Stephan2007]_
    .. math::
            \frac{ds}{dt} &= x - \kappa\,s - \gamma \,(f-1) \\
            \frac{df}{dt} &= s \\
            \frac{dv}{dt} &= \frac{1}{\tau_o} \, (f - v^{1/\alpha})\\
            \frac{dq}{dt} &= \frac{1}{\tau_o}(f \, \frac{1-(1-E_0)^{1/\alpha}}{E_0} - v^{&/\alpha} \frac{q}{v})\\
            \kappa &= \frac{1}{\tau_s}\\
            \gamma &= \frac{1}{\tau_f}
    """

    s = state_variables[0, :]
    f = state_variables[1, :]
    v = state_variables[2, :]
    q = state_variables[3, :]

    x = neural_input[0, :]

    ds = x - (1. / self.tau_s) * s - (1. / self.tau_f) * (f - 1)
    df = s
    dv = (1. / self.tau_o) * (f - v ** (1. / self.alpha))
    dq = (1. / self.tau_o) * ((f * (1. - (1. - self.E0) ** (1. / f)) / self.E0) -
                              (v ** (1. / self.alpha)) * (q / v))

    return numpy.array([ds, df, dv, dq])

# %%
import sys

# %%
[print(i) for i in sys.path]
# Out:
# /Users/pfc/projects/tvb-fnirs/scratch
# /usr/local/Cellar/python@3.10/3.10.4/Frameworks/Python.framework/Versions/3.10/lib/python310.zip
# /usr/local/Cellar/python@3.10/3.10.4/Frameworks/Python.framework/Versions/3.10/lib/python3.10
# /usr/local/Cellar/python@3.10/3.10.4/Frameworks/Python.framework/Versions/3.10/lib/python3.10/lib-dynload
#
# /usr/local/Cellar/ipython/8.3.0/libexec/lib/python3.10/site-packages
# /usr/local/opt/six/lib/python3.10/site-packages
# /Users/pfc/Library/Python/3.10/lib/python/site-packages
# /usr/local/lib/python3.10/site-packages
# [None, None, None, None, None, None, None, None, None]
